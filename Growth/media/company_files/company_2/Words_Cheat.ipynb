# %%
pip install english_words
# Out:
# ...
#      |████████████████████████████████| 352 kB 2.4 MB/s eta 0:00:01
# ...
#   Created wheel for english-words: filename=english_words-1.0.3-py3-none-any.whl size=352083 sha256=a7d97d663025cbe69a07ea4d0e87b1ed726f47f9da0be35ce5d8e53965020cdb
#   Stored in directory: /Users/zhangzhengyi/Library/Caches/pip/wheels/a8/e6/be/028f88f1b1fd742fa710dd72a583813f6245b8528b8e6cbaf8
# Successfully built english-words
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from english_words import english_words_set

# %%
# Returns Set of words not longer than n
def shortwords(n):
    return {w for w in english_words_set if len(w) <=n}

# %%
# Numpy array - Returns List of words no longer than n
def shortwords2(n):
    words = np.array(list(english_words_set))
    return set(words[np.char.str_len(words)<=n])

# %%
import time
start_time = time.time()
game_words1 = shortwords1(7)
print("List: --- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
game_words2 = shortwords2(7)
print("np.array: --- %s seconds ---" % (time.time() - start_time))
# Out:
# List: --- 0.01376199722290039 seconds ---
# np.array: --- 0.09114193916320801 seconds ---

# %%
# Words game cheating
# input String of available word options
def cheat(options):
    return set(game_words)

# %%
words = np.array(list(english_words_set))
set(words[np.char.str_len(words)<=5])
# Out:
# {'hose',
#  'Neal',
#  'Togo',
#  'lurid',
#  'fair',
#  'ppm',
#  'maul',
#  'bundy',
#  'baby',
#  'boom',
#  'rajah',
#  'theft',
#  'usage',
#  'theme',
#  'staff',
#  'mare',
#  'en',
#  'USN',
#  'clod',
#  'faro',
#  'curve',
#  'shuck',
#  'tusk',
#  'kill',
#  'rate',
#  'handy',
#  'pupal',
#  'live',
#  'lose',
#  'jenny',
#  'cry',
#  'funk',
#  'send',
#  'tug',
#  'toddy',
#  'July',
#  'tapir',
#  'lady',
#  'fiat',
#  'Bosch',
#  'fix',
#  'rasp',
#  'snake',
#  'IBM',
#  'Salem',
#  'don',
#  'Ghana',
#  'roast',
#  'furl',
#  'lo',
#  'skein',
#  'Bowen',
#  'Karl',
#  'pact',
#  'loud',
#  'cheap',
#  'QED',
#  'Paoli',
#  'carp',
#  'smite',
#  'elk',
#  'SIAM',
#  'hack',
#  'yell',
#  'type',
#  'San',
#  'demur',
#  'glib',
#  'guild',
#  'amuse',
#  'sigh',
#  'lolly',
#  'rink',
#  'sidle',
#  'hurt',
#  'Heine',
#  'train',
#  'Maier',
#  'ratio',
#  'wrath',
#  'Emile',
#  'Korea',
#  'choke',
#  'grey',
#  'nonce',
#  'mixup',
#  'grate',
#  'rooky',
# ...

# %%
game_words1
# Out:
# {'dainty',
#  'hose',
#  'insipid',
#  'Neal',
#  'Togo',
#  'lurid',
#  'fair',
#  'ppm',
#  'Antoine',
#  'burley',
#  'grotto',
#  'maul',
#  'premise',
#  'dharma',
#  'airlift',
#  'abridge',
#  'bundy',
#  'astray',
#  'virile',
#  'baby',
#  'boom',
#  'quetzal',
#  'Creole',
#  'crocus',
#  'panicle',
#  'rajah',
#  'seduce',
#  'theft',
#  'instill',
#  'usage',
#  'theme',
#  'Ottoman',
#  'Bentley',
#  'staff',
#  'krypton',
#  'mare',
#  'en',
#  'farther',
#  'USN',
#  'enough',
#  'clod',
#  'faro',
#  'curve',
#  'Kenney',
#  'shuck',
#  'tusk',
#  'kill',
#  'prodigy',
#  'rate',
#  'uterine',
#  'handy',
#  'Huston',
#  'pupal',
#  'live',
#  'lose',
#  'pertain',
#  'jenny',
#  'cry',
#  'funk',
#  'Albany',
#  'send',
#  'tug',
#  'toddy',
#  'Melvin',
#  'mukluk',
#  'inject',
#  'July',
#  'Kelley',
#  'intact',
#  'tapir',
#  'ascend',
#  'wheedle',
#  'lady',
#  'erotica',
#  'huzzah',
#  'emitted',
#  'zither',
#  'fiat',
#  'Bosch',
#  'scrubby',
#  'fix',
# ...

# %%
arr = np.array([1,2,3])
arr[arr<=2]
# Out:
# array([1, 2])

# %%
game_words.flat

# %%
words_set = set(shortwords1(7))
"stupid" in words_set
# Out:
# False
